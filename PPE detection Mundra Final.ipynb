# %%
from ultralytics import YOLO
import cvzone
import cv2
import math
from pygame import mixer

import csv
import time
from datetime import datetime



def write_in_csv(rows):
    with open (r'YOUR_CSV_FILE.csv','r+',newline='') as file:
        file_write=csv.writer(file)
        for val in rows:
            file.write.writerow(val)



mixer.init()
mixer.music.load("download.mp3")


# Running real time from webcam
#cap = cv2.VideoCapture('buildingworker.mp4')
cap=cv2.VideoCapture(0)
#cap=cv2.VideoCapture("rtsp://tapoadmin:sharada2022@192.168.0.186/stream2/")# PKR Home
#model = YOLO('yolov8s.pt')
model = YOLO('best.pt')
#model = YOLO('best_arcsuite_mp_n.pt')
#model = YOLO('best_arcsuite_mp_bg.pt')




# Reading the classes
#classnames = ['Arcsuite','No_Arcsuite']
#classnames=['Arcsuite','No-arcsuite']
#classnames=['Helmet','Safety_Jacket','No_Helmet','No_Safety_Jacket']
#names = ['Hardhat', 'Mask', 'NO-Hardhat', 'NO-Mask', 'NO-Safety Vest', 'Person', 'Safety Cone',
#    'Safety Vest', 'machinery', 'vehicle']

names = ['Helmet', 'Mask', 'NO-Helmet', 'NO-Mask', 'NO-Safety Jacket', 'Person', 'Safety Cone',
    'Safety Jacket', 'machinery', 'vehicle']



while True:
    ret,frame = cap.read()
    frame = cv2.resize(frame,(1080,860))
    #frame = cv2.resize(frame,(640,640))
    result = model(frame,stream=True)
    

    # Getting bbox,confidence and class names informations to work with
    for info in result:
        boxes = info.boxes
        for box in boxes:
            confidence = box.conf[0]
            confidence = math.ceil(confidence * 100)
            Class = int(box.cls[0])
            if confidence > 65:
                x1,y1,x2,y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1),int(y1),int(x2),int(y2)
                cv2.rectangle(frame,(x1,y1),(x2,y2),(0,0,255),5)
                cvzone.putTextRect(frame, f'{names[Class]} {confidence}%', [x1 + 8, y1 + 100],
                                   scale=1.5,thickness=2)
                cvzone.putTextRect(frame, f'{names[Class]}', [x1 + 8, y1 + 100],
                                   scale=1.5,thickness=2)
                
#                if (names[Class]=='NO-Hardhat' and names[Class]=='NO-Safety Vest'):
                if (names[Class]=='NO-Helmet'):
                    if not mixer.music.get_busy():
                        mixer.music.play()
                        print("Detection Active")
                    
                    
                # Terminate run when "Q" pressed
    if cv2.waitKey(1) == ord("q"):
        break





    cv2.imshow('APL Mundra PPE Detection',frame)
    cv2.waitKey(1)
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 512x640 1 Hardhat, 1 NO-Mask, 1 Person, 1 Safety Vest, 178.4ms
# Speed: 6.2ms preprocess, 178.4ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 211.8ms
# Speed: 8.5ms preprocess, 211.8ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 165.5ms
# Speed: 3.0ms preprocess, 165.5ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 173.6ms
# Speed: 5.0ms preprocess, 173.6ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 169.3ms
# Speed: 4.3ms preprocess, 169.3ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 512x640 1 Hardhat, 1 NO-Mask, 1 NO-Safety Vest, 1 Person, 156.2ms
# Speed: 4.4ms preprocess, 156.2ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# ...

# %%
pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import cvzone
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import cvzone
#
# ModuleNotFoundError: No module named 'cvzone'

# %%
pip install cvzone
# Out:
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cvzone: filename=cvzone-1.6.1-py3-none-any.whl size=26308 sha256=1cfa3fea08e361ff1ed8bb37298300a836c7e7c7e8aac8848af47475310c0c42
#   Stored in directory: c:\users\30006140\appdata\local\pip\cache\wheels\ab\36\ec\47be2d4e59dc4289e684d5b0dde54d1e72e51a614e57690e85
# Successfully built cvzone
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))': /simple/cvzone/
# ...

# %%
pip install pygame
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pygame from https://files.pythonhosted.org/packages/82/61/93ae7afbd931a70510cfdf0a7bb0007540020b8d80bc1d8762ebdc46479b/pygame-2.5.2-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/10.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/10.8 MB 640.0 kB/s eta 0:00:17
#    ---------------------------------------- 0.1/10.8 MB 777.7 kB/s eta 0:00:14
#     --------------------------------------- 0.1/10.8 MB 944.1 kB/s eta 0:00:12
#     --------------------------------------- 0.2/10.8 MB 1.2 MB/s eta 0:00:09
#    - -------------------------------------- 0.5/10.8 MB 2.2 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/10.8 MB 3.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.2/10.8 MB 3.5 MB/s eta 0:00:03
#    ------- -------------------------------- 2.2/10.8 MB 5.5 MB/s eta 0:00:02
# ...

# %%
import torch

# %%
CFG.BASE_MODEL_WEIGHTS
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 CFG.BASE_MODEL_WEIGHTS
#
# NameError: name 'CFG' is not defined

# %%
streamlit run PPE_Detection
# Out:
#   Cell In[10], line 1
#     streamlit run PPE_Detection
#               ^
# SyntaxError: invalid syntax
